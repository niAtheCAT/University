# %% [markdown]
# *italic* **bold**
#
# _italic_ __bold__
#
#
# Header 1
# ===========
#
# Header 2
# -----------------------
#
# http://example.com
#
# * Item 1
# * Item 2
#   * item 2a
#   * item 2b
#
# 1. item 1
# 2. item 2
# 3. item 3
#     * item 3a
#     * item 3b
#
# Roses are red,
# [Vialets are blue.](http://example.com)
#
#
# A friend  once said:
#
# > It,s always better to give
# > than to recieve.
#
# ```{r}
# summery(cars$dist)
#
# summery(cars$speed)
# ```
#
# There were  'r nrow(cars)' cars studied
#
# ```
# Hello (preformated)
# ```
#
# We define `add` function.
#
# ![text](Pictures\CatTemperAvatar.png)
#
# ------------
#
# $equation$
#
# $latex equation$
#
# \( equation \)
#
# *********
#
# $$ equation $$
#
# $$latex equation $$
#
# \[ equation \]
#
# first | second
# ----- | ------
# 1 | 2
# 3 | 4
